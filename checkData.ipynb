# %%
dataFilePath = "/Users/dharshid/CDIPS_Project/data/EP_data.csv"
import pandas as pd
EPData = pd.read_csv(dataFilePath)

# %%
EPData.columns
# Out:
# Index([u'gender', u'num_groups', u'num_entries', u'num_fans', u'num_friends',
#        u'created', u'last_login', u'num_logins', u'last_wall_activity',
#        u'last_circle_activity', u'birthdate', u'gid', u'content',
#        u'date_posted', u'votes', u'num_comments'],
#       dtype='object')

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf-8')

# %%
noGroupsUsers = EPData[EPData['num_groups'] == 0]

# %%
noGroupsUsers
# Out:
#        gender  num_groups  num_entries  num_fans  num_friends     created  \
# 2           U           0        65535      5672            0  2008-04-21
# 75          U           0        65535      5672            0  2008-04-21
# 85          U           0        65535      5672            0  2008-04-21
# 112         U           0        65535      5672            0  2008-04-21
# 167         U           0        65535      5672            0  2008-04-21
# 173         U           0        65535      5672            0  2008-04-21
# 176         U           0        65535      5672            0  2008-04-21
# 201         U           0        65535      5672            0  2008-04-21
# 220         U           0        65535      5672            0  2008-04-21
# 231         U           0        65535      5672            0  2008-04-21
# 260         U           0        65535      5672            0  2008-04-21
# 399         U           0        65535      5672            0  2008-04-21
# ...

# %%
EPData.loc[531099,:]
# Out:
# gender                                                                  F
# num_groups                                                              0
# num_entries                                                            28
# num_fans                                                                1
# num_friends                                                             0
# created                                                        2015-06-20
# last_login                                            2015-07-09 10:25:36
# num_logins                                                             57
# last_wall_activity                                    2015-07-09 12:57:31
# last_circle_activity                                  2015-07-07 13:44:18
# birthdate                                                      1964-11-30
# gid                                                                  3657
# content                 <iframe title="YouTube video player" class="yo...
# ...

# %%
noGroupsFemales = noGroupsUsers[noGroupsUsers['gender']=='F']

# %%
noGroupsFemales.sort(columns='created')
# Out:
#        gender  num_groups  num_entries  num_fans  num_friends     created  \
# 388303      F           0            2         1            0  2010-02-18
# 346613      F           0           53        25           17  2010-09-26
# 139524      F           0           53        25           17  2010-09-26
# 495416      F           0           53        25           17  2010-09-26
# 123029      F           0           53        25           17  2010-09-26
# 127956      F           0           53        25           17  2010-09-26
# 197590      F           0           53        25           17  2010-09-26
# 405651      F           0           53        25           17  2010-09-26
# 408193      F           0           53        25           17  2010-09-26
# 391019      F           0            2         1            0  2011-04-21
# 391018      F           0            2         1            0  2011-04-21
# 391281      F           0            8         3            0  2011-12-01
# ...

# %%
groupNameFile = "/Users/dharshid/CDIPS_Project/data/group_names.csv"
groupNames = pd.read_csv(groupNameFile,header=None,names=['gid','group_name'])

# %%
groupNames.columns
# Out:
# Index([u'gid', u'group_name'], dtype='object')

# %%
groupNames[groupNames['gid']==109]
# Out:
#     gid         group_name
# 89  109  Battle Depression

# %%
EPData.sort(columns='birthdate')
# Out:
#        gender  num_groups  num_entries  num_fans  num_friends     created  \
# 228959      T          24            1         5            4  2015-03-27
# 129897      M           7            1         1            1  2015-02-18
# 3232        F           7            2         1            0  2015-01-02
# 3237        F           7            2         1            0  2015-01-02
# 290909      F           9            1         1            1  2015-04-21
# 119849      F          74           14         9            5  2014-11-15
# 70996       F          74           14         9            5  2014-11-15
# 341         F          74           14         9            5  2014-11-15
# 119780      F          74           14         9            5  2014-11-15
# 71007       F          74           14         9            5  2014-11-15
# 79210       F          74           14         9            5  2014-11-15
# 71013       F          74           14         9            5  2014-11-15
# ...

# %%
dataFileWithUserIDs = "/Users/dharshid/CDIPS_Project/data/First100000_with_id.csv"
dataWithUserIDs = pd.read_csv(dataFileWithUserIDs)

# %%
dataWithUserIDs.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1 gender  num_groups  num_entries  \
# 0           0             0             0      F         210           54
# 1           1             1             1      F          25            9
# 2           2             3             3      M         153            2
# 3           3             4             4      F          29            8
# 4           4             5             5      M          14            1
# 5           5             6             6      F        2993           62
# 6           6             7             7      F          69           26
# 7           7             8             8      M         250          255
# 8           8             9             9      F          41           80
# 9           9            10            10      M         263          104
#
#    num_fans  num_friends     created           last_login    ...      \
# 0        25            2  2014-12-20  2015-04-03 12:45:01    ...
# ...

# %%
dataWithUserIDs.columns
# Out:
# Index([u'Unnamed: 0', u'Unnamed: 0.1', u'Unnamed: 0.1', u'gender',
#        u'num_groups', u'num_entries', u'num_fans', u'num_friends', u'created',
#        u'last_login', u'num_logins', u'last_wall_activity',
#        u'last_circle_activity', u'birthdate', u'gid', u'content',
#        u'date_posted', u'votes', u'num_comments', u'age', u'uid',
#        u'certainty'],
#       dtype='object')

# %%
dataSorted = dataWithUserIDs.sort(columns='uid')
dataSorted
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1 gender  num_groups  num_entries  \
# 41477       41477         43822         43822      M        1261         1847
# 38577       38577         40748         40748      M         127          208
# 38579       38579         40750         40750      M         127          208
# 75670       75670         80054         80054    NaN         114           10
# 10865       10865         11512         11512      F          27           15
# 38644       38644         40817         40817    NaN          76            9
# 20296       20296         21448         21448      M         339           49
# 60474       60474         63909         63909    NaN           1            1
# 53080       53080         56164         56164    NaN           1            1
# 38680       38680         40855         40855      M          42           39
# 92176       92176         97530         97530    NaN           1            1
# ...

# %%
dataSorted[~(dataSorted['uid']==0)]
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1 gender  num_groups  num_entries  \
# 69383       69383         73372         73372      F        1412          733
# 50974       50974         53949         53949      F          30           28
# 44768       44768         47303         47303      F           2            3
# 22952       22952         24230         24230      F           9            7
# 592           592           611           611      F         249          206
# 62602       62602         66152         66152      F          25           26
# 30338       30338         32050         32050      F          25           26
# 50084       50084         52991         52991      F          25           26
# 78678       78678         83202         83202      F          59          126
# 94794       94794        100309        100309      F         161          179
# 93040       93040         98449         98449      F         161          179
# ...

# %%
dataGroupSorted = dataWithUserIDs.sort(columns = 'gid')
dataGroupSorted
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1 gender  num_groups  num_entries  \
# 24525       24525         25890         25890      M         679          153
# 93434       93434         98864         98864      F         400          470
# 94681       94681        100190        100190      M         189           20
# 23445       23445         24751         24751      F          39           14
# 10122       10122         10733         10733      F          76           25
# 39325       39325         41545         41545      M         527          117
# 76085       76085         80488         80488      F         140           59
# 39508       39508         41740         41740      F         541          358
# 53727       53727         56836         56836      F          40           15
# 63641       63641         67234         67234      M         577          140
# 5237         5237          5575          5575      F          93           23
# ...

# %%
EPBirthdateSorted = EPData.sort(columns='birthdate')
EPBirthdateSorted
# Out:
#        gender  num_groups  num_entries  num_fans  num_friends     created  \
# 228959      T          24            1         5            4  2015-03-27
# 129897      M           7            1         1            1  2015-02-18
# 3232        F           7            2         1            0  2015-01-02
# 3237        F           7            2         1            0  2015-01-02
# 290909      F           9            1         1            1  2015-04-21
# 119849      F          74           14         9            5  2014-11-15
# 70996       F          74           14         9            5  2014-11-15
# 341         F          74           14         9            5  2014-11-15
# 119780      F          74           14         9            5  2014-11-15
# 71007       F          74           14         9            5  2014-11-15
# 79210       F          74           14         9            5  2014-11-15
# 71013       F          74           14         9            5  2014-11-15
# ...

# %%
EPBirthdateSorted.iloc[50000:50050,:]
# Out:
#        gender  num_groups  num_entries  num_fans  num_friends     created  \
# 389555      M         104           26        15            6  2014-03-10
# 219454      F           9            1         1            1  2015-03-25
# 76197       F         713           97       890           67  2014-01-03
# 317884    NaN          67            9        23           19  2015-03-20
# 227174      F         713           97       890           67  2014-01-03
# 20321       F         713           97       890           67  2014-01-03
# 391036      M           0            1         1            1  2015-03-14
# 17412       M        1090           22        25           14  2014-12-17
# 412785      F         713           97       890           67  2014-01-03
# 500929      F         713           97       890           67  2014-01-03
# 119710      F         713           97       890           67  2014-01-03
# 361863      F         713           97       890           67  2014-01-03
# ...

# %%
tempData = EPData[EPData['birthdate']=='1966-11-30']
tempData[['created','gender']]
# Out:
#            created gender
# 7297    2014-12-17      M
# 7368    2014-12-17      M
# 10549   2014-12-17      M
# 10926   2014-07-28      M
# 11859   2014-01-03      F
# 11897   2014-12-17      M
# 11973   2014-12-17      M
# 12132   2014-12-17      M
# 12336   2014-12-17      M
# 13736   2014-12-17      M
# 14605   2014-12-17      M
# 14664   2014-07-20      F
# 17412   2014-12-17      M
# 17591   2014-12-17      M
# 18145   2014-07-28      M
# 19786   2014-12-28      M
# 20183   2014-12-17      M
# 20244   2014-07-28      M
# 20321   2014-01-03      F
# 20404   2012-05-11      M
# 20408   2012-05-11      M
# 20409   2012-05-11      M
# 20433   2014-07-28      M
# 31582   2014-12-28      M
# 41807   2014-12-17      M
# 43077   2014-12-17      M
# 46310   2014-07-28      M
# 51247   2014-07-28      M
# 62034   2014-07-28      M
# 62349   2014-01-03      F
# ...            ...    ...
# 460736  2015-06-08      F
# 472449  2015-02-03      F
# 472453  2015-02-03      F
# ...

# %%
import sys
def makeUserGroupDict(data, uidCol, gidCol):
    print "starting function"
    sys.stdout.flush()
    data = data.sort(columns='uid')
    print "Finished sorting!"
    sys.stdout.flush()
    userDict = {}
    dictUID = data.iloc[0,uidCol]
    userDict[dictUID] = {}
    print "Starting to fill dict"
    sys.stdout.flush()
    for irow in range(0,data.shape[0]):
        if irow%100 == 0:
            print "Row number is ", irow, " of ", data.shape[0]
            sys.stdout.flush()
        currentUID = data.iloc[irow,uidCol]
        if dictUID != currentUID:
            dictUID = currentUID
            userDict[dictUID] = {}
        gid = data.iloc[irow,gidCol]
        if gid in userDict[dictUID]:
            userDict[dictUID][gid] += 1
        else:
            userDict[dictUID][gid] = 1
            
    return userDict

# %%
goodData = dataWithUserIDs[~(dataWithUserIDs['uid']==0)]
goodData
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1 gender  num_groups  num_entries  \
# 0               0             0             0      F         210           54
# 1               1             1             1      F          25            9
# 2               2             3             3      M         153            2
# 3               3             4             4      F          29            8
# 4               4             5             5      M          14            1
# 5               5             6             6      F        2993           62
# 6               6             7             7      F          69           26
# 7               7             8             8      M         250          255
# 8               8             9             9      F          41           80
# 9               9            10            10      M         263          104
# 10             10            11            11      F         167           13
# ...

# %%
goodData = goodData[goodData['certainty']==True]
goodData
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1 gender  num_groups  num_entries  \
# 3               3             4             4      F          29            8
# 4               4             5             5      M          14            1
# 5               5             6             6      F        2993           62
# 6               6             7             7      F          69           26
# 8               8             9             9      F          41           80
# 9               9            10            10      M         263          104
# 10             10            11            11      F         167           13
# 11             11            12            12      M         304           25
# 12             12            13            13      F          26           45
# 13             13            14            14      F          26           14
# 14             14            15            15      F         118          100
# ...

# %%
goodDataSorted = goodData.sort(columns='uid')
goodDataSorted
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1 gender  num_groups  num_entries  \
# 69383       69383         73372         73372      F        1412          733
# 50974       50974         53949         53949      F          30           28
# 44768       44768         47303         47303      F           2            3
# 22952       22952         24230         24230      F           9            7
# 592           592           611           611      F         249          206
# 30338       30338         32050         32050      F          25           26
# 50084       50084         52991         52991      F          25           26
# 62602       62602         66152         66152      F          25           26
# 78678       78678         83202         83202      F          59          126
# 93054       93054         98464         98464      F         161          179
# 93040       93040         98449         98449      F         161          179
# ...

# %%
goodData.shape
# Out:
# (75673, 22)

# %%
goodDataSubset = goodData.iloc[0:10000,:]

# %%
userDict = makeUserGroupDict(goodDataSubset, 20, 14)

# %%
userDict
# Out:
# {9068545: {557163: 1},
#  9297924: {115562: 1},
#  9385901: {53805: 1},
#  8888331: {36156: 1},
#  9388046: {25978: 1},
#  9388051: {332: 1},
#  8936110: {1431: 1},
#  5881878: {973354: 1},
#  6635543: {133371: 1},
#  8126489: {1783: 1},
#  2029794: {241469: 1},
#  9371677: {692409: 1},
#  9170949: {2510: 1},
#  8478752: {128197: 1},
#  7471139: {972453: 1},
#  9379877: {2779: 1},
#  9296561: {973362: 1},
#  9379883: {973082: 1},
#  9348469: {128760: 1, 157943: 1},
#  9388078: {50460: 1},
#  9306159: {392478: 1},
#  6103088: {973946: 1},
#  8437809: {183: 1},
#  9347127: {108256: 1},
#  9379898: {180597: 1},
#  9363515: {627398: 1},
#  7774268: {1409: 1},
#  8675389: {23323: 1},
#  7561279: {32430: 1},
#  7823426: {2425: 1},
#  9199627: {752095: 1},
#  6856773: {323567: 1},
#  9379912: {668250: 1},
#  9388105: {717557: 1},
#  8634442: {63246: 1},
#  9396301: {117528: 1},
#  9396302: {109654: 1},
#  5685328: {880544: 1, 911206: 1},
#  9394872: {973587: 1},
#  9011282: {973241: 1},
# ...

# %%
totalEntries = 0
for key in userDict.keys():
    dictLen = len(userDict[key])
    print dictLen
    totalEntries += dictLen

# %%
for i in range(0,2):
    print i
i
# Out:
# 1

# %%
goodData.iloc[0:150,[14,20]]
# Out:
#         gid      uid
# 3    970365  9367848
# 4    262541  7581701
# 5    261634  8626454
# 6     88442  8267845
# 8    368043  9166441
# 9     36977  8128714
# 10      495  9374607
# 11   565765  9318024
# 12   293608  9087949
# 13   473848  9382904
# 14   488521  9166429
# 15   627239  7938998
# 17     3941  9364093
# 19   395178  8149149
# 20   395247  8449220
# 21   293608  9087949
# 22    59004  9379414
# 23      335  9335149
# 24   427042  8939668
# 25   675119  9357924
# 26   293608  8167713
# 27   173000  7812690
# 29      185  9184454
# 30   972256  6609242
# 31     2389  9351351
# 32   117528  9357495
# 33   160526  9226988
# 35     8436  2050477
# 36     1340  8905023
# 38   640484  6769181
# ..      ...      ...
# 153  363594  8876773
# 156  270467  8128714
# 157    9074  9238698
# 159  592832  2171042
# 160    9041  9383214
# 161  972276  8929122
# 162   14065  8147946
# 163    7258  8242449
# 164    1647  8367344
# 166    1340  9290938
# 167  555013  9052745
# ...

# %%
userDict2 = makeUserGroupDict(goodData.iloc[0:150,:],20,14)

# %%
userDict2
# Out:
# {2050477: {8436: 1},
#  2171042: {592832: 1},
#  2338798: {972263: 1},
#  2529477: {293463: 1},
#  2992395: {104699: 1},
#  3505192: {967473: 1},
#  4086293: {453278: 1},
#  4308942: {61: 1},
#  5749365: {233: 1},
#  5783256: {239092: 1},
#  5876098: {27995: 1},
#  5897203: {298475: 1},
#  6053020: {293608: 1},
#  6504361: {17036: 1},
#  6609242: {972256: 1},
#  6683320: {7366: 1},
#  6749444: {84950: 1},
#  6769181: {640484: 1},
#  6900282: {972277: 1},
#  6926900: {2510: 1},
#  7046590: {834927: 1},
#  7382675: {12159: 1},
#  7516104: {972264: 1},
#  7581701: {262541: 1},
#  7684856: {395178: 1},
#  7733234: {17709: 1},
#  7812690: {173000: 1},
#  7889763: {291932: 1},
#  7938998: {627239: 1},
#  8028451: {972279: 1},
#  8128714: {13643: 1},
#  8147946: {14065: 1},
#  8149149: {395178: 1},
#  8155992: {156353: 1},
#  8167713: {293608: 1},
#  8242449: {7258: 1},
#  8258225: {16727: 1},
#  8267845: {203939: 1},
#  8367344: {1960: 1},
#  8384457: {395178: 1},
#  8446685: {51293: 1},
# ...

# %%
len(userDict2)
# Out:
# 100

# %%
totalEntries = 0
for key in userDict2.keys():
    totalEntries += len(userDict2[key])

# %%
totalEntries
# Out:
# 102

# %%
goodDataSorted = goodData.sort(columns='uid')

# %%
goodDataSorted.iloc[0:25,[14,20]]
# Out:
#           gid    uid
# 69383   13512   1062
# 50974     247   2168
# 44768  181576   3243
# 22952    9648   6193
# 592    972333  44448
# 30338    2510  47289
# 50084    2510  47289
# 62602    2510  47289
# 78678   63676  47664
# 93054    8450  49208
# 93040    6156  49208
# 92440     310  49208
# 94277     310  49208
# 94893   17806  49208
# 91420  453672  49208
# 94794  989529  49208
# 92462    9902  49208
# 94760  989529  49208
# 91410    2332  49208
# 59611  321718  50049
# 62769  321718  50049
# 97240  989996  50049
# 38673  980251  50049
# 25137  976977  50049
# 95070  522535  53997

# %%
userDict3 = makeUserGroupDict(goodDataSorted.iloc[0:25,:],20,14)

# %%
userDict3[49208]
# Out:
# {310: 2, 2332: 1, 6156: 1, 8450: 1, 9902: 1, 17806: 1, 453672: 1, 989529: 2}

# %%
totalEntries = 0
for ukey in userDict3.keys():
    for gkey in userDict3[ukey].keys():
        totalEntries += userDict3[ukey][gkey]

# %%
totalEntries
# Out:
# 25

# %%
userDict4 = makeUserGroupDict(goodData.iloc[0:25,:],20,14)

# %%
goodData.iloc[0:25,[14,20]]
# Out:
#        gid      uid
# 3   970365  9367848
# 4   262541  7581701
# 5   261634  8626454
# 6    88442  8267845
# 8   368043  9166441
# 9    36977  8128714
# 10     495  9374607
# 11  565765  9318024
# 12  293608  9087949
# 13  473848  9382904
# 14  488521  9166429
# 15  627239  7938998
# 17    3941  9364093
# 19  395178  8149149
# 20  395247  8449220
# 21  293608  9087949
# 22   59004  9379414
# 23     335  9335149
# 24  427042  8939668
# 25  675119  9357924
# 26  293608  8167713
# 27  173000  7812690
# 29     185  9184454
# 30  972256  6609242
# 31    2389  9351351

# %%
userDict4
# Out:
# {6609242: {972256: 1},
#  7581701: {262541: 1},
#  7812690: {173000: 1},
#  7938998: {627239: 1},
#  8128714: {36977: 1},
#  8149149: {395178: 1},
#  8167713: {293608: 1},
#  8267845: {88442: 1},
#  8449220: {395247: 1},
#  8626454: {261634: 1},
#  8939668: {427042: 1},
#  9087949: {293608: 2},
#  9166429: {488521: 1},
#  9166441: {368043: 1},
#  9184454: {185: 1},
#  9318024: {565765: 1},
#  9335149: {335: 1},
#  9351351: {2389: 1},
#  9357924: {675119: 1},
#  9364093: {3941: 1},
#  9367848: {970365: 1},
#  9374607: {495: 1},
#  9379414: {59004: 1},
#  9382904: {473848: 1}}

# %%
len(userDict4)
# Out:
# 24

# %%
len(goodData.iloc[0:25,:])
# Out:
# 25

# %%
totalEntries = 0
for ukey in userDict4.keys():
    for gkey in userDict4[ukey].keys():
        totalEntries += userDict4[ukey][gkey]

# %%
totalEntries
# Out:
# 25

# %%
temp = goodData.iloc[0:25,:]

# %%
tempSorted = temp.sort(columns = 'uid')

# %%
tempSorted.iloc[:,[14,20]]
# Out:
#        gid      uid
# 30  972256  6609242
# 4   262541  7581701
# 27  173000  7812690
# 15  627239  7938998
# 9    36977  8128714
# 19  395178  8149149
# 26  293608  8167713
# 6    88442  8267845
# 20  395247  8449220
# 5   261634  8626454
# 24  427042  8939668
# 21  293608  9087949
# 12  293608  9087949
# 14  488521  9166429
# 8   368043  9166441
# 29     185  9184454
# 11  565765  9318024
# 23     335  9335149
# 31    2389  9351351
# 25  675119  9357924
# 17    3941  9364093
# 3   970365  9367848
# 10     495  9374607
# 22   59004  9379414
# 13  473848  9382904

# %%
userDict4[9087949]
# Out:
# {293608: 1}

# %%
userDict5 = makeUserGroupDict(tempSorted,20,14)

# %%
len(userDict5)
# Out:
# 24

# %%
userDict5[9087949]
# Out:
# {293608: 2}

# %%
temp.sort(columns='uid')
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1 gender  num_groups  num_entries  \
# 30          30            31            31      M         239           61
# 4            4             5             5      M          14            1
# 27          27            28            28      F           9            7
# 15          15            16            16      F        1601           10
# 9            9            10            10      M         263          104
# 19          19            20            20      F         177           10
# 26          26            27            27      F         247           22
# 6            6             7             7      F          69           26
# 20          20            21            21      F          58           17
# 5            5             6             6      F        2993           62
# 24          24            25            25      F         140           13
# ...

# %%
temp.iloc[0,20]
# Out:
# 9367848

# %%
temp
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1 gender  num_groups  num_entries  \
# 3            3             4             4      F          29            8
# 4            4             5             5      M          14            1
# 5            5             6             6      F        2993           62
# 6            6             7             7      F          69           26
# 8            8             9             9      F          41           80
# 9            9            10            10      M         263          104
# 10          10            11            11      F         167           13
# 11          11            12            12      M         304           25
# 12          12            13            13      F          26           45
# 13          13            14            14      F          26           14
# 14          14            15            15      F         118          100
# ...

# %%
groupNameFile = "/Users/dharshid/CDIPS_Project/data/group_names.csv"
groupNames = pd.read_csv(groupNameFile,names=['gid','group_name'],header=None)

# %%
groupNames
# Out:
#             gid                                         group_name
# 0            20                                            Love U2
# 1            21                                     Love Dane Cook
# 2            22                               Love Pablo Francisco
# 3            23                                  Love George Lopez
# 4            24                                    Love Bill Cosby
# 5            25                      Had In-office Teeth Whitening
# 6            26                                    Love Chris Rock
# 7            27                              Love David Hasselhoff
# 8            28                               Love Stephen Colbert
# 9            29                                  Love John Stewart
# 10           30                                 Love Conan O'brien
# 11           31                                      Love Jay Leno
# 12           32                               Love David Letterman
# ...

# %%
tempSorted
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1 gender  num_groups  num_entries  \
# 30          30            31            31      M         239           61
# 4            4             5             5      M          14            1
# 27          27            28            28      F           9            7
# 15          15            16            16      F        1601           10
# 9            9            10            10      M         263          104
# 19          19            20            20      F         177           10
# 26          26            27            27      F         247           22
# 6            6             7             7      F          69           26
# 20          20            21            21      F          58           17
# 5            5             6             6      F        2993           62
# 24          24            25            25      F         140           13
# ...

# %%
tempGID = tempSorted['gid'].values

# %%
tempGID
