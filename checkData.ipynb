# %%
dataFilePath = "/Users/dharshid/CDIPS_Project/data/EP_data.csv"
import pandas as pd
EPData = pd.read_csv(dataFilePath)

# %%
EPData.columns
# Out:
# Index([u'gender', u'num_groups', u'num_entries', u'num_fans', u'num_friends',
#        u'created', u'last_login', u'num_logins', u'last_wall_activity',
#        u'last_circle_activity', u'birthdate', u'gid', u'content',
#        u'date_posted', u'votes', u'num_comments'],
#       dtype='object')

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf-8')

# %%
noGroupsUsers = EPData[EPData['num_groups'] == 0]

# %%
noGroupsUsers
# Out:
#        gender  num_groups  num_entries  num_fans  num_friends     created  \
# 2           U           0        65535      5672            0  2008-04-21
# 75          U           0        65535      5672            0  2008-04-21
# 85          U           0        65535      5672            0  2008-04-21
# 112         U           0        65535      5672            0  2008-04-21
# 167         U           0        65535      5672            0  2008-04-21
# 173         U           0        65535      5672            0  2008-04-21
# 176         U           0        65535      5672            0  2008-04-21
# 201         U           0        65535      5672            0  2008-04-21
# 220         U           0        65535      5672            0  2008-04-21
# 231         U           0        65535      5672            0  2008-04-21
# 260         U           0        65535      5672            0  2008-04-21
# 399         U           0        65535      5672            0  2008-04-21
# ...

# %%
EPData.loc[531099,:]
# Out:
# gender                                                                  F
# num_groups                                                              0
# num_entries                                                            28
# num_fans                                                                1
# num_friends                                                             0
# created                                                        2015-06-20
# last_login                                            2015-07-09 10:25:36
# num_logins                                                             57
# last_wall_activity                                    2015-07-09 12:57:31
# last_circle_activity                                  2015-07-07 13:44:18
# birthdate                                                      1964-11-30
# gid                                                                  3657
# content                 <iframe title="YouTube video player" class="yo...
# ...

# %%
noGroupsFemales = noGroupsUsers[noGroupsUsers['gender']=='F']

# %%
noGroupsFemales.sort(columns='created')
# Out:
#        gender  num_groups  num_entries  num_fans  num_friends     created  \
# 388303      F           0            2         1            0  2010-02-18
# 346613      F           0           53        25           17  2010-09-26
# 139524      F           0           53        25           17  2010-09-26
# 495416      F           0           53        25           17  2010-09-26
# 123029      F           0           53        25           17  2010-09-26
# 127956      F           0           53        25           17  2010-09-26
# 197590      F           0           53        25           17  2010-09-26
# 405651      F           0           53        25           17  2010-09-26
# 408193      F           0           53        25           17  2010-09-26
# 391019      F           0            2         1            0  2011-04-21
# 391018      F           0            2         1            0  2011-04-21
# 391281      F           0            8         3            0  2011-12-01
# ...
