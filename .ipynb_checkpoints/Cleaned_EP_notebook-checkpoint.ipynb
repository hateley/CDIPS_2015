# %%
# The following iPython notebook shows how to take a series of text inputs
# (in this case status updates on the Experience Project), pre-process the
# text to remove extraneous words, HTML, and punctuation, and create a 
# bag of words that allows the user to further train random forest models.
# In this example, I stop at a point where the most common words in the 
# test set have been found.

#import the whole data file
import pandas as pd       
extext = pd.read_csv("EP_data.csv", header=0)
#id_text = pd.read_csv("EP_data.csv", header=0, usecols=[11,12])
extext.shape
print extext.head()
# Out:
#   gender  num_groups  num_entries  num_fans  num_friends     created  \
# 0      F         210           54        25            2  2014-12-20
# 1      F          25            9         2            0  2014-08-28
# 2      U           0        65535      5672            0  2008-04-21
# 3      M         153            2         6            5  2014-12-13
# 4      F          29            8        83           60  2014-12-27
#
#             last_login  num_logins   last_wall_activity last_circle_activity  \
# 0  2015-04-03 12:45:01           6  0000-00-00 00:00:00  0000-00-00 00:00:00
# 1  2015-04-15 22:32:36          19  0000-00-00 00:00:00  0000-00-00 00:00:00
# 2  2012-11-13 18:03:23           5  2009-03-27 21:22:12  0000-00-00 00:00:00
# 3  2015-06-01 20:34:52          15  0000-00-00 00:00:00  2014-12-13 08:37:11
# 4  2015-05-14 13:25:09          19  0000-00-00 00:00:00  2015-05-14 13:25:34
#
#     birthdate     gid                                            content  \
# 0  1997-03-31  124249  I just want my mom to hug me and say that she ...
# 1  1994-03-31    5276  I don't know why this is happening right now. ...
# 2  1989-03-09   49025  I accept the wisdom of all religions and disca...
# 3  1993-11-30   58852  HAPPY NEW  YEARS !!!!!!!!!!!!!!!     !!!!!!!!!...
# 4  1977-08-31  970365  Showing now if anyone is interested...message ...
#
#            date_posted  votes  num_comments
# 0  2015-01-01 00:00:10      0             0
# 1  2015-01-01 00:00:46      0             0
# 2  2015-01-01 00:00:49     10             1
# 3  2015-01-01 00:02:39      1             2
# 4  2015-01-01 00:02:45      0             0

# %%
extext.shape[0] #what size is our dataset?
# Out:
# 534305

# %%
#I can select only the columns I want
from sklearn.cross_validation import train_test_split

data = extext[['gid','content','gender']]
ntrain = 10000
data_train, data_test = train_test_split(data, train_size=ntrain)

subset= data_train
subset.index = range(subset.shape[0])
print subset.shape, data_test.shape
# Out:
# (10000, 3) (524305, 3)

# %%
from bs4 import BeautifulSoup
import re
import nltk
#nltk.download()
from nltk.corpus import stopwords # Import the stop word list
def status_to_words( raw_status ):
    # Function to convert a raw status to a string of words
    # The input is a single string (a raw status update), and 
    # the output is a single string (a preprocessed status update)
    #
    # 1. Remove HTML
    status_text = BeautifulSoup(raw_status).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", status_text)
    # remove http URLs
    letters_only = re.sub(r'^https?:\/\/.*[\r\n]*', '', letters_only)
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))
    #Remove 'm' and 'hasn' from the text
    stops = stops.union([u'hasn',u'm',u've',u'll',u're',u'didn',u'us',u'im',u'doesn',u'couldn',u'won',u'isn',u'http',u'www']) 
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))


#Let's see an example of what status_to_words does
clean_status = status_to_words( subset['content'][1] )
print (clean_status)
# Out:
# inbox meh friends

# %%
#How many statuses do we have? Should be same as row number of extext.shape above
num_status = subset["content"].size
print num_status
# Out:
# 10000

# %%
#Now run status_to_words on all the statuses (or a subset) for preprocessing
print "Cleaning and parsing the status updates...\n"
clean_statuses = []
#num_status = subset["content"].size #for full set
num_status = ntrain #for subset of all statuses
for i in xrange( 0, num_status ):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print "Status %d of %d\n" % ( i+1, num_status )                                                                    
    clean_statuses.append( status_to_words( subset["content"][i] ))
# Out:
# Cleaning and parsing the status updates...
#
# Status 1000 of 10000
#
# Status 2000 of 10000
#
# Status 3000 of 10000
#
# Status 4000 of 10000
#
# Status 5000 of 10000
#
# Status 6000 of 10000
#
# Status 7000 of 10000
#
# Status 8000 of 10000
#
# Status 9000 of 10000
#
# Status 10000 of 10000

# %%
# create the Bag o' words. Each word that appears in the statuses after preprocessing gets a place
# in the bag (list). Each status gets a list denoting the number of times a particular word
# shows up in that status.  Check out 
# https://www.kaggle.com/c/word2vec-nlp-tutorial/details/part-1-for-beginners-bag-of-words

print "Creating the bag of words...\n"
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool. Note that some of the preprocessing steps above
# can be done directly with this tool; we may want to do that.
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 500) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(clean_statuses)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()
# Out:
# Creating the bag of words...

# %%
# so we see it's 15000 rows (corresponging to the the 15000 statuses)
# and 5000 columns (corresponding to the top 5000 words used in the
# statuses). Increase "max_features" in CountVectorizer to increase
# the number of words.

import numpy as np

#get the column names (the words in the bag)
vocab = vectorizer.get_feature_names() 

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print count, tag
# Out:
# 389 able
# 429 actually
# 143 afraid
# 358 age
# 149 agemeet
# 321 ago
# 168 air
# 365 almost
# 501 alone
# 186 along
# 293 already
# 927 also
# 146 although
# 1266 always
# 195 amazing
# 543 another
# 179 answer
# 151 anxiety
# 327 anymore
# 788 anyone
# 762 anything
# 142 anyway
# 842 around
# 337 ask
# 460 asked
# 172 attention
# 741 away
# 217 baby
# 1467 back
# 623 bad
# 147 barb
# 349 beautiful
# 151 became
# 308 become
# 323 bed
# 178 behind
# 475 believe
# 698 best
# 623 better
# 432 big
# 339 bit
# 196 black
# 424 body
# 184 book
# 216 boy
# 253 boyfriend
# 162 break
# 151 bring
# 188 brother
# 201 business
# 283 call
# 301 called
# 460 came
# 159 cannot
# 174 cant
# 269 car
# 499 care
# 270 cause
# 149 chance
# 315 change
# 155 chat
# 157 check
# 248 child
# 291 children
# 180 choose
# 147 church
# 306 close
# 143 clothes
# 147 cold
# 504 com
# 645 come
# 250 comes
# 197 coming
# 175 company
# 218 completely
# 143 connected
# 157 contact
# 187 control
# 1411 could
# 221 couple
# 215 course
# 190 crazy
# 167 cry
# 163 cut
# 319 dad
# 199 date
# 368 dating
# 159 daughter
# 1466 day
# 496 days
# 385 de
# 176 deal
# 226 decided
# 170 deep
# 171 depression
# 161 die
# 412 different
# 143 dog
# 441 done
# 339 dont
# 241 door
# 214 dream
# 158 dreams
# 155 easy
# 177 eat
# 227 either
# 471 else
# 144 emotional
# 166 en
# 422 end
# 148 ended
# 197 engine
# 222 enjoy
# 460 enough
# 200 ep
# 155 especially
# 152 et
# 142 etc
# 1711 even
# 812 ever
# 803 every
# 202 everyday
# 559 everyone
# 668 everything
# 147 ex
# 296 experience
# 423 eyes
# 408 face
# 240 fact
# 181 fall
# 628 family
# 277 far
# 260 father
# 162 fear
# 2003 feel
# 530 feeling
# 211 feelings
# 248 feels
# 540 felt
# 307 finally
# 856 find
# 901 first
# 143 food
# 161 forever
# 411 found
# 333 free
# 668 friend
# 1029 friends
# 192 front
# 250 full
# 246 fun
# 172 future
# 232 gave
# 2441 get
# 225 gets
# 624 getting
# 630 girl
# 143 girlfriend
# 372 girls
# 547 give
# 150 given
# 1576 go
# 678 god
# 185 goes
# 1227 going
# 252 gone
# 150 gonna
# 1371 good
# 144 google
# 1238 got
# 508 great
# 223 group
# 297 guess
# 494 guy
# 385 guys
# 246 hair
# 191 half
# 358 hand
# 232 hands
# 221 happen
# 268 happened
# 620 happy
# 574 hard
# 496 hate
# 252 haven
# 395 head
# 276 hear
# 169 heard
# 560 heart
# 188 hell
# 881 help
# 336 high
# 176 hit
# 239 hold
# 751 home
# 397 hope
# 179 hot
# 200 hours
# 443 house
# 202 however
# 179 huge
# 212 human
# 363 hurt
# 332 husband
# 192 idea
# 196 important
# 395 inside
# 172 instead
# 151 interested
# 207 internet
# 150 issues
# 288 job
# 583 keep
# 191 kept
# 306 kids
# 312 kind
# 144 kiss
# 384 knew
# 2721 know
# 168 knowing
# 217 knows
# 195 la
# 619 last
# 284 later
# 149 le
# 148 learn
# 253 least
# 362 leave
# 463 left
# 219 less
# 791 let
# 2078 life
# 204 light
# 4029 like
# 167 listen
# 826 little
# 520 live
# 173 lives
# 287 living
# 325 lol
# 793 long
# 190 longer
# 728 look
# 307 looked
# 637 looking
# 331 lost
# 566 lot
# 2692 love
# 299 loved
# 215 loving
# 747 made
# 1353 make
# 507 makes
# 312 making
# 719 man
# 843 many
# 153 marketing
# 142 marriage
# 218 married
# 274 matter
# 693 may
# 422 maybe
# 338 mean
# 283 meet
# 909 men
# 330 message
# 283 met
# 356 might
# 557 mind
# 192 mine
# 161 minutes
# 242 miss
# 413 mom
# 241 moment
# 284 money
# 172 month
# 402 months
# 214 morning
# 434 mother
# 159 mouth
# 219 move
# 164 moved
# 1376 much
# 215 music
# 250 must
# 173 naked
# 279 name
# 1022 need
# 188 needed
# 202 needs
# 1642 never
# 816 new
# 423 next
# 348 nice
# 638 night
# 148 normal
# 617 nothing
# 225 often
# 282 oh
# 197 ok
# 172 okay
# 578 old
# 627 older
# 2817 one
# 156 ones
# 247 online
# 254 open
# 440 others
# 159 outside
# 332 pain
# 372 parents
# 358 part
# 329 past
# 2278 people
# 283 perfect
# 855 person
# 214 phone
# 426 place
# 147 platform
# 254 play
# 157 playing
# 465 please
# 325 point
# 155 possible
# 180 post
# 353 pretty
# 259 probably
# 219 problem
# 143 problems
# 495 put
# 181 question
# 249 quite
# 169 rather
# 304 read
# 182 reading
# 182 ready
# 429 real
# 152 realize
# 1760 really
# 302 reason
# 143 recently
# 494 relationship
# 384 remember
# 170 rest
# 971 right
# 359 room
# 194 run
# 141 running
# 234 sad
# 1048 said
# 280 saw
# 1003 say
# 258 saying
# 257 says
# 227 scared
# 635 school
# 328 search
# 196 second
# 1299 see
# 159 seeing
# 164 seem
# 236 seems
# 220 seen
# 319 self
# 161 sense
# 142 serious
# 191 set
# 173 several
# 335 sex
# 260 share
# 213 short
# 325 show
# 163 sick
# 254 side
# 649 since
# 219 single
# 223 sister
# 156 sit
# 391 site
# 195 skin
# 287 sleep
# 249 small
# 199 smile
# 182 social
# 1215 someone
# 991 something
# 556 sometimes
# 331 son
# 157 song
# 246 soon
# 230 sorry
# 163 soul
# 171 special
# 177 stand
# 373 start
# 680 started
# 148 starting
# 298 stay
# 1100 still
# 411 stop
# 161 stopped
# 142 stories
# 304 story
# 204 strong
# 266 stuff
# 183 stupid
# 177 support
# 488 sure
# 811 take
# 260 taking
# 788 talk
# 333 talking
# 719 tell
# 177 telling
# 201 thank
# 701 thing
# 1191 things
# 1506 think
# 328 thinking
# 517 though
# 682 thought
# 200 thoughts
# 213 three
# 2297 time
# 519 times
# 235 tired
# 526 today
# 481 together
# 745 told
# 379 took
# 220 top
# 171 touch
# 145 towards
# 317 tried
# 291 true
# 187 truly
# 258 trust
# 178 truth
# 542 try
# 498 trying
# 195 turn
# 214 turned
# 636 two
# 164 un
# 366 understand
# 435 use
# 373 used
# 184 usually
# 222 wait
# 146 waiting
# 218 walk
# 150 walked
# 146 walking
# 232 wanna
# 2445 want
# 581 wanted
# 317 wants
# 362 wasn
# 234 watch
# 180 watching
# 177 water
# 1272 way
# 166 ways
# 172 wear
# 168 wearing
# 250 web
# 450 website
# 276 week
# 209 weeks
# 165 weight
# 160 weird
# 1009 well
# 682 went
# 160 whatever
# 213 white
# 290 whole
# 379 wife
# 446 wish
# 186 within
# 516 without
# 436 woman
# 801 women
# 172 wonder
# 175 word
# 306 words
# 705 work
# 221 working
# 707 world
# 187 worse
# 2368 would
# 260 wouldn
# 192 write
# 371 wrong
# 643 year
# 1051 years
# 343 yes
# 150 yesterday
# 343 yet
# 271 young
# 406 younger

# %%
#let's order them by frequency

testwords = zip(vocab, dist)
for tag, count in sorted(testwords, key=lambda testwords: testwords[1], reverse=True):
    print count, tag
# Out:
# 4029 like
# 2817 one
# 2721 know
# 2692 love
# 2445 want
# 2441 get
# 2368 would
# 2297 time
# 2278 people
# 2078 life
# 2003 feel
# 1760 really
# 1711 even
# 1642 never
# 1576 go
# 1506 think
# 1467 back
# 1466 day
# 1411 could
# 1376 much
# 1371 good
# 1353 make
# 1299 see
# 1272 way
# 1266 always
# 1238 got
# 1227 going
# 1215 someone
# 1191 things
# 1100 still
# 1051 years
# 1048 said
# 1029 friends
# 1022 need
# 1009 well
# 1003 say
# 991 something
# 971 right
# 927 also
# 909 men
# 901 first
# 881 help
# 856 find
# 855 person
# 843 many
# 842 around
# 826 little
# 816 new
# 812 ever
# 811 take
# 803 every
# 801 women
# 793 long
# 791 let
# 788 anyone
# 788 talk
# 762 anything
# 751 home
# 747 made
# 745 told
# 741 away
# 728 look
# 719 man
# 719 tell
# 707 world
# 705 work
# 701 thing
# 698 best
# 693 may
# 682 thought
# 682 went
# 680 started
# 678 god
# 668 everything
# 668 friend
# 649 since
# 645 come
# 643 year
# 638 night
# 637 looking
# 636 two
# 635 school
# 630 girl
# 628 family
# 627 older
# 624 getting
# 623 bad
# 623 better
# 620 happy
# 619 last
# 617 nothing
# 583 keep
# 581 wanted
# 578 old
# 574 hard
# 566 lot
# 560 heart
# 559 everyone
# 557 mind
# 556 sometimes
# 547 give
# 543 another
# 542 try
# 540 felt
# 530 feeling
# 526 today
# 520 live
# 519 times
# 517 though
# 516 without
# 508 great
# 507 makes
# 504 com
# 501 alone
# 499 care
# 498 trying
# 496 days
# 496 hate
# 495 put
# 494 guy
# 494 relationship
# 488 sure
# 481 together
# 475 believe
# 471 else
# 465 please
# 463 left
# 460 asked
# 460 came
# 460 enough
# 450 website
# 446 wish
# 443 house
# 441 done
# 440 others
# 436 woman
# 435 use
# 434 mother
# 432 big
# 429 actually
# 429 real
# 426 place
# 424 body
# 423 eyes
# 423 next
# 422 end
# 422 maybe
# 413 mom
# 412 different
# 411 found
# 411 stop
# 408 face
# 406 younger
# 402 months
# 397 hope
# 395 head
# 395 inside
# 391 site
# 389 able
# 385 de
# 385 guys
# 384 knew
# 384 remember
# 379 took
# 379 wife
# 373 start
# 373 used
# 372 girls
# 372 parents
# 371 wrong
# 368 dating
# 366 understand
# 365 almost
# 363 hurt
# 362 leave
# 362 wasn
# 359 room
# 358 age
# 358 hand
# 358 part
# 356 might
# 353 pretty
# 349 beautiful
# 348 nice
# 343 yes
# 343 yet
# 339 bit
# 339 dont
# 338 mean
# 337 ask
# 336 high
# 335 sex
# 333 free
# 333 talking
# 332 husband
# 332 pain
# 331 lost
# 331 son
# 330 message
# 329 past
# 328 search
# 328 thinking
# 327 anymore
# 325 lol
# 325 point
# 325 show
# 323 bed
# 321 ago
# 319 dad
# 319 self
# 317 tried
# 317 wants
# 315 change
# 312 kind
# 312 making
# 308 become
# 307 finally
# 307 looked
# 306 close
# 306 kids
# 306 words
# 304 read
# 304 story
# 302 reason
# 301 called
# 299 loved
# 298 stay
# 297 guess
# 296 experience
# 293 already
# 291 children
# 291 true
# 290 whole
# 288 job
# 287 living
# 287 sleep
# 284 later
# 284 money
# 283 call
# 283 meet
# 283 met
# 283 perfect
# 282 oh
# 280 saw
# 279 name
# 277 far
# 276 hear
# 276 week
# 274 matter
# 271 young
# 270 cause
# 269 car
# 268 happened
# 266 stuff
# 260 father
# 260 share
# 260 taking
# 260 wouldn
# 259 probably
# 258 saying
# 258 trust
# 257 says
# 254 open
# 254 play
# 254 side
# 253 boyfriend
# 253 least
# 252 gone
# 252 haven
# 250 comes
# 250 full
# 250 must
# 250 web
# 249 quite
# 249 small
# 248 child
# 248 feels
# 247 online
# 246 fun
# 246 hair
# 246 soon
# 242 miss
# 241 door
# 241 moment
# 240 fact
# 239 hold
# 236 seems
# 235 tired
# 234 sad
# 234 watch
# 232 gave
# 232 hands
# 232 wanna
# 230 sorry
# 227 either
# 227 scared
# 226 decided
# 225 gets
# 225 often
# 223 group
# 223 sister
# 222 enjoy
# 222 wait
# 221 couple
# 221 happen
# 221 working
# 220 seen
# 220 top
# 219 less
# 219 move
# 219 problem
# 219 single
# 218 completely
# 218 married
# 218 walk
# 217 baby
# 217 knows
# 216 boy
# 215 course
# 215 loving
# 215 music
# 214 dream
# 214 morning
# 214 phone
# 214 turned
# 213 short
# 213 three
# 213 white
# 212 human
# 211 feelings
# 209 weeks
# 207 internet
# 204 light
# 204 strong
# 202 everyday
# 202 however
# 202 needs
# 201 business
# 201 thank
# 200 ep
# 200 hours
# 200 thoughts
# 199 date
# 199 smile
# 197 coming
# 197 engine
# 197 ok
# 196 black
# 196 important
# 196 second
# 195 amazing
# 195 la
# 195 skin
# 195 turn
# 194 run
# 192 front
# 192 idea
# 192 mine
# 192 write
# 191 half
# 191 kept
# 191 set
# 190 crazy
# 190 longer
# 188 brother
# 188 hell
# 188 needed
# 187 control
# 187 truly
# 187 worse
# 186 along
# 186 within
# 185 goes
# 184 book
# 184 usually
# 183 stupid
# 182 reading
# 182 ready
# 182 social
# 181 fall
# 181 question
# 180 choose
# 180 post
# 180 watching
# 179 answer
# 179 hot
# 179 huge
# 178 behind
# 178 truth
# 177 eat
# 177 stand
# 177 support
# 177 telling
# 177 water
# 176 deal
# 176 hit
# 175 company
# 175 word
# 174 cant
# 173 lives
# 173 naked
# 173 several
# 172 attention
# 172 future
# 172 instead
# 172 month
# 172 okay
# 172 wear
# 172 wonder
# 171 depression
# 171 special
# 171 touch
# 170 deep
# 170 rest
# 169 heard
# 169 rather
# 168 air
# 168 knowing
# 168 wearing
# 167 cry
# 167 listen
# 166 en
# 166 ways
# 165 weight
# 164 moved
# 164 seem
# 164 un
# 163 cut
# 163 sick
# 163 soul
# 162 break
# 162 fear
# 161 die
# 161 forever
# 161 minutes
# 161 sense
# 161 stopped
# 160 weird
# 160 whatever
# 159 cannot
# 159 daughter
# 159 mouth
# 159 outside
# 159 seeing
# 158 dreams
# 157 check
# 157 contact
# 157 playing
# 157 song
# 156 ones
# 156 sit
# 155 chat
# 155 easy
# 155 especially
# 155 possible
# 153 marketing
# 152 et
# 152 realize
# 151 anxiety
# 151 became
# 151 bring
# 151 interested
# 150 given
# 150 gonna
# 150 issues
# 150 walked
# 150 yesterday
# 149 agemeet
# 149 chance
# 149 le
# 148 ended
# 148 learn
# 148 normal
# 148 starting
# 147 barb
# 147 church
# 147 cold
# 147 ex
# 147 platform
# 146 although
# 146 waiting
# 146 walking
# 145 towards
# 144 emotional
# 144 google
# 144 kiss
# 143 afraid
# 143 clothes
# 143 connected
# 143 dog
# 143 food
# 143 girlfriend
# 143 problems
# 143 recently
# 142 anyway
# 142 etc
# 142 marriage
# 142 serious
# 142 stories
# 141 running

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(n_estimators = 100)

# %%
forest = forest.fit( train_data_features, subset["gender"] )

# %%
ntest = 20000
data_test = data_test[:ntest]
data_test.index = range(data_test.shape[0])
data_test.head()
# Out:
#        gid                                            content gender
# 0   828259            go ahead ,I'll be as honest as possible      M
# 1  1025005  Anyone ever tried this?,  multiple times?,  ma...      M
# 2   968499  I got this game for my birthday last year and ...      M
# 3   381536             throw me against the wall and choke me      F
# 4   353615  i have a Fit body so i hope i can find boyfrie...      F

# %%
clean_test_statuses = [] 

print "Cleaning and parsing the test statuses...\n"
for i in xrange(0,num_test):
    if( (i+1) % 1000 == 0 ):
        print "Status %d of %d\n" % (i+1, ntest)
    clean_status = status_to_words( data_test["content"][i] )
    clean_test_statuses.append( clean_status )

# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_statuses)
test_data_features = test_data_features.toarray()
vocab = vectorizer.get_feature_names() 

# Sum up the counts of each vocabulary word
dist = np.sum(test_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print count, tag
# Out:
# Cleaning and parsing the test statuses...
#
# Status 1000 of 20000
#
# Status 2000 of 20000
#
# Status 3000 of 20000
#
# Status 4000 of 20000
#
# Status 5000 of 20000
#
# Status 6000 of 20000
#
# Status 7000 of 20000
#
# Status 8000 of 20000
#
# Status 9000 of 20000
#
# Status 10000 of 20000
#
# 354 able
# 394 actually
# 153 afraid
# 328 age
# 115 agemeet
# 334 ago
# 105 air
# 362 almost
# 470 alone
# 186 along
# 270 already
# 881 also
# 134 although
# 1179 always
# 219 amazing
# 539 another
# 148 answer
# 112 anxiety
# 298 anymore
# 777 anyone
# 681 anything
# 162 anyway
# 789 around
# 369 ask
# 374 asked
# 159 attention
# 679 away
# 213 baby
# 1357 back
# 576 bad
# 24 barb
# 384 beautiful
# 148 became
# 262 become
# 323 bed
# 177 behind
# 462 believe
# 605 best
# 621 better
# 405 big
# 315 bit
# 270 black
# 406 body
# 119 book
# 161 boy
# 256 boyfriend
# 146 break
# 152 bring
# 192 brother
# 167 business
# 314 call
# 254 called
# 479 came
# 147 cannot
# 143 cant
# 220 car
# 515 care
# 259 cause
# 174 chance
# 322 change
# 192 chat
# 136 check
# 231 child
# 205 children
# 147 choose
# 93 church
# 292 close
# 154 clothes
# 125 cold
# 351 com
# 657 come
# 240 comes
# 188 coming
# 157 company
# 173 completely
# 115 connected
# 142 contact
# 183 control
# 1289 could
# 245 couple
# 200 course
# 194 crazy
# 175 cry
# 133 cut
# 328 dad
# 157 date
# 277 dating
# 156 daughter
# 1498 day
# 484 days
# 227 de
# 145 deal
# 212 decided
# 157 deep
# 151 depression
# 177 die
# 380 different
# 94 dog
# 426 done
# 324 dont
# 184 door
# 278 dream
# 174 dreams
# 169 easy
# 189 eat
# 200 either
# 450 else
# 107 emotional
# 102 en
# 438 end
# 159 ended
# 118 engine
# 230 enjoy
# 422 enough
# 315 ep
# 197 especially
# 33 et
# 150 etc
# 1602 even
# 752 ever
# 810 every
# 129 everyday
# 556 everyone
# 620 everything
# 129 ex
# 303 experience
# 371 eyes
# 399 face
# 243 fact
# 186 fall
# 594 family
# 263 far
# 217 father
# 144 fear
# 1981 feel
# 548 feeling
# 213 feelings
# 201 feels
# 538 felt
# 292 finally
# 843 find
# 808 first
# 173 food
# 154 forever
# 437 found
# 353 free
# 707 friend
# 976 friends
# 162 front
# 248 full
# 303 fun
# 160 future
# 225 gave
# 2232 get
# 195 gets
# 549 getting
# 641 girl
# 141 girlfriend
# 416 girls
# 576 give
# 143 given
# 1450 go
# 476 god
# 192 goes
# 1052 going
# 222 gone
# 181 gonna
# 1218 good
# 122 google
# 1128 got
# 462 great
# 185 group
# 273 guess
# 420 guy
# 354 guys
# 231 hair
# 176 half
# 307 hand
# 211 hands
# 198 happen
# 256 happened
# 594 happy
# 570 hard
# 543 hate
# 211 haven
# 336 head
# 233 hear
# 189 heard
# 506 heart
# 158 hell
# 886 help
# 296 high
# 145 hit
# 219 hold
# 664 home
# 359 hope
# 170 hot
# 237 hours
# 447 house
# 189 however
# 118 huge
# 147 human
# 366 hurt
# 314 husband
# 183 idea
# 171 important
# 334 inside
# 172 instead
# 170 interested
# 163 internet
# 143 issues
# 241 job
# 513 keep
# 192 kept
# 302 kids
# 303 kind
# 152 kiss
# 366 knew
# 2562 know
# 140 knowing
# 183 knows
# 125 la
# 644 last
# 284 later
# 18 le
# 144 learn
# 240 least
# 365 leave
# 496 left
# 210 less
# 736 let
# 1787 life
# 179 light
# 3825 like
# 144 listen
# 780 little
# 518 live
# 161 lives
# 265 living
# 353 lol
# 712 long
# 176 longer
# 680 look
# 239 looked
# 597 looking
# 309 lost
# 571 lot
# 2481 love
# 296 loved
# 201 loving
# 721 made
# 1240 make
# 434 makes
# 295 making
# 609 man
# 832 many
# 75 marketing
# 140 marriage
# 231 married
# 270 matter
# 500 may
# 466 maybe
# 337 mean
# 285 meet
# 736 men
# 341 message
# 248 met
# 321 might
# 477 mind
# 187 mine
# 166 minutes
# 273 miss
# 514 mom
# 232 moment
# 271 money
# 172 month
# 316 months
# 265 morning
# 318 mother
# 113 mouth
# 209 move
# 137 moved
# 1333 much
# 210 music
# 207 must
# 163 naked
# 276 name
# 1067 need
# 184 needed
# 183 needs
# 1539 never
# 737 new
# 406 next
# 343 nice
# 624 night
# 173 normal
# 562 nothing
# 251 often
# 313 oh
# 228 ok
# 176 okay
# 597 old
# 473 older
# 2877 one
# 157 ones
# 216 online
# 305 open
# 417 others
# 190 outside
# 342 pain
# 301 parents
# 315 part
# 296 past
# 2215 people
# 236 perfect
# 778 person
# 215 phone
# 401 place
# 124 platform
# 247 play
# 159 playing
# 427 please
# 308 point
# 159 possible
# 209 post
# 281 pretty
# 251 probably
# 233 problem
# 143 problems
# 505 put
# 140 question
# 216 quite
# 165 rather
# 273 read
# 124 reading
# 147 ready
# 375 real
# 167 realize
# 1708 really
# 318 reason
# 163 recently
# 455 relationship
# 370 remember
# 178 rest
# 895 right
# 360 room
# 176 run
# 115 running
# 238 sad
# 1065 said
# 277 saw
# 925 say
# 242 saying
# 415 says
# 186 scared
# 594 school
# 211 search
# 195 second
# 1323 see
# 153 seeing
# 179 seem
# 183 seems
# 245 seen
# 332 self
# 136 sense
# 98 serious
# 145 set
# 171 several
# 307 sex
# 194 share
# 162 short
# 269 show
# 165 sick
# 223 side
# 618 since
# 244 single
# 215 sister
# 161 sit
# 271 site
# 167 skin
# 319 sleep
# 221 small
# 203 smile
# 148 social
# 1172 someone
# 989 something
# 481 sometimes
# 165 son
# 151 song
# 241 soon
# 182 sorry
# 165 soul
# 131 special
# 162 stand
# 377 start
# 613 started
# 130 starting
# 268 stay
# 1122 still
# 421 stop
# 141 stopped
# 129 stories
# 270 story
# 151 strong
# 232 stuff
# 170 stupid
# 188 support
# 441 sure
# 810 take
# 221 taking
# 684 talk
# 330 talking
# 710 tell
# 156 telling
# 154 thank
# 650 thing
# 1164 things
# 1434 think
# 332 thinking
# 527 though
# 587 thought
# 218 thoughts
# 242 three
# 2159 time
# 478 times
# 207 tired
# 572 today
# 435 together
# 767 told
# 329 took
# 199 top
# 185 touch
# 128 towards
# 313 tried
# 257 true
# 174 truly
# 172 trust
# 166 truth
# 552 try
# 438 trying
# 206 turn
# 190 turned
# 588 two
# 49 un
# 345 understand
# 410 use
# 395 used
# 205 usually
# 184 wait
# 137 waiting
# 224 walk
# 159 walked
# 133 walking
# 253 wanna
# 2310 want
# 517 wanted
# 239 wants
# 301 wasn
# 241 watch
# 182 watching
# 184 water
# 1185 way
# 124 ways
# 216 wear
# 179 wearing
# 216 web
# 358 website
# 293 week
# 212 weeks
# 170 weight
# 170 weird
# 880 well
# 683 went
# 147 whatever
# 148 white
# 294 whole
# 332 wife
# 510 wish
# 168 within
# 487 without
# 453 woman
# 752 women
# 172 wonder
# 157 word
# 235 words
# 708 work
# 231 working
# 646 world
# 153 worse
# 2264 would
# 232 wouldn
# 170 write
# 367 wrong
# 571 year
# 1006 years
# 322 yes
# 129 yesterday
# 352 yet
# 241 young
# 344 younger

# %%
# Use the random forest to make sentiment label predictions
result = forest.predict(test_data_features)

# Copy the results to a pandas dataframe with an "id" column and
# a "sentiment" column
output = pd.DataFrame( data={"gid":data_test["gid"], "P_gender":result,"R_gender":data_test['gender']} )

# Use pandas to write the comma-separated output file
#output.to_csv( "Bag_of_Words_model.csv", index=False, quoting=3 )

# %%
P_correct = round(sum(output['P_gender']==output['R_gender']),2)/ntest
P_correct
# Out:
# 0.256

# %%
print "ntest=",ntest
# Out:
# ntest= 20000

# %%
import random_forest as rf
import pandas as pd

# %%
#EP = pd.read_csv("EP_data.csv", header=0).dropna()
target = 'gender'
ntrain = 10000
ntest = 5000
result = rf.rand_forest_predict(EP,'content',target,ntrain,ntest,nfeature=1000,nestimator=50)
# Out:
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://www.youtube.com/watch?v=k4V3Mo61fJM&list=PLzyYbaYKbahnEmFJFyxlURFHhSc74l5C7" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://www.youtube.com/watch?v=ruyaKdPfTN4" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Cleaning and parsing train statuses...
#
# Status 1000 of 10000
#
# Status 2000 of 10000
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://youtu.be/HMDqMGj3wrM" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://m.facebook.com/sara.chuhdary/photos/a.10151101478830083.778751.140086685082/10155408861880083/?type=1&source=48" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Status 3000 of 10000
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://youtu.be/JTT2LEyjdC4" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://www.youtube.com/watch?v=dQw4w9WgXcQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://youtu.be/yNzDAQkGUYU" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://m.huffpost.com/us/entry/6786776" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://www.youtube.com/watch?v=HSgN5EWKi9Y" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://youtu.be/cLqbsYWPDO0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Status 4000 of 10000
#
# Status 5000 of 10000
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://www.youtube.com/watch?v=1cQh1ccqu8M" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://fooplot.com/plot/9401vtr8gb" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Status 6000 of 10000
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://m.facebook.com/bluebirdpoetry" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://scontent-mia.xx.fbcdn.net/hvideo-xpf1/v/t42.1790-2/10980984_627336460705519_1638969741_n.mp4?oh=1cfd9b7660b64fc61e54138ec0b6eb6b&oe=54F9E228" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://www.youtube.com/watch?v=vqWO-1PPdgE&list=FLnK5x1XVcfvzYSMw_3VXNTw&index=2" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Status 7000 of 10000
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://youtu.be/yCC_b5WHLX0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://youtu.be/8335hP2iim0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Status 8000 of 10000
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://www.youtube.com/watch?v=l5LjNh4JtpQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://youtu.be/ddLd0QRf7Vg?list=PLC0A6F2B5A9E6A80D" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://soundcloud.com/kehlanimusic/kehlani-alive-feat-coucheron" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://www.thepoliticalinsider.com/crazy-muslims-food-stamps-demand-food-meet-islamic-requirements-video/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Status 9000 of 10000
#
# Status 10000 of 10000
#
# Creating the bag of words...
#
# Fitting to a random forest with  50  parameters...
#
# Cleaning and parsing test statuses...
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://www.youtube.com/watch?v=EfPMDVQ4Oc4" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://youtu.be/KmucVmr60HQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Status 1000 of 5000
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://youtu.be/KJRQMzKu4AM" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://timesofindia.indiatimes.com/nri/us-canada-news/pio-teen-cracks-all-8-ivy-league-schools-plus-6/articleshow/46893091.cms" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://youtu.be/-GugzLSbOQE" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://www.lifesitenews.com/blogs/my-son-found-the-photo-album-we-kept-of-my-pregnancy-with-him-his-response" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Status 2000 of 5000
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://www.youtube.com/watch?v7fh=5PLzgG70&feature=share" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://www.facebook.com/story.php?story_fbid=10153104702242238&id=579192237" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Status 3000 of 5000
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://beforeitsnews.com/christian-news/2015/03/come-out-of-her-2509944.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://www.truth-out.org/news/item/28919-activist-publishes-book-of-hate-mail-from-bible-believing-christians-bible-believers-respond-by-you-guessed-it" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Status 4000 of 5000
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://youtu.be/VlMEGBsw6j8" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://youtu.be/WLTbFaoZuVQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# Status 5000 of 5000
#
# Creating the bag of words...
# /Users/Jade/anaconda/envs/python2/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "http://youtu.be/ql8zSQ71NW0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)

# %%
print "The proportion of correct prediction for ",target, " is ", 
round(sum(result['Prediction']==result['True Value']),2)/ntest
# Out:
#  The proportion of correct prediction for  gender  is
# 0.4624
