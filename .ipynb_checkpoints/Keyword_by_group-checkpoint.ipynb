# %%
import pandas as pd
import age_grouping as ag
import keywords_by_group as kbg
import warnings
warnings.filterwarnings("ignore")

# %%
EPData = pd.read_csv("../First100000.csv")

# %%
## Group data by a given bin size
age_range = [13,78]
bin_size = 11
Data = ag.age_filtering(EPData,age_range)
Data = ag.age_grouping(Data,bin_size,age_range)
group = list(set(Data['age_group']))
nfeature = 20

# %%
kbg.keyword_by_group(Data,'age_group','content',nfeature,False,True)
# Out:
# age_group 0
# Creating the bag of words...
#
# 12755 know
# 11759 love
# 11073 people
# 10000 feel
# 9334 time
# 8137 life
# 7258 think
# 7183 never
# 6836 go
# 6301 always
# 6289 someone
# 5964 day
# 5914 friends
# 5804 back
# 5598 see
# 5529 going
# 5395 things
# 5231 got
# 5121 still
# 4993 way
# age_group 1
# Creating the bag of words...
#
# 12179 search
# 11145 time
# 9468 site
# 9151 know
# 9117 people
# 9006 web
# 8037 engine
# 7256 love
# 6845 feel
# 6786 also
# 6536 may
# 6388 day
# 6298 website
# 6233 life
# 6210 need
# 6056 new
# 5844 way
# 5714 see
# 5456 use
# 5330 well
# age_group 2
# Creating the bag of words...
#
# 4546 love
# 3715 time
# 3493 know
# 3058 life
# 2566 people
# 2414 feel
# 2386 never
# 2384 go
# 2343 back
# 2193 day
# 2127 think
# 2036 see
# 1903 way
# 1844 always
# 1821 years
# 1795 got
# 1786 things
# 1733 going
# 1685 still
# 1614 said
# age_group 3
# Creating the bag of words...
#
# 2821 time
# 2347 love
# 2198 know
# 2014 life
# 1884 back
# 1837 said
# 1749 day
# 1727 people
# 1681 see
# 1542 go
# 1397 got
# 1388 way
# 1360 years
# 1334 think
# 1328 never
# 1316 feel
# 1257 well
# 1198 going
# 1150 man
# 1134 always
# age_group 4
# Creating the bag of words...
#
# 1839 god
# 1019 com
# 1012 world
# 960 time
# 947 life
# 933 love
# 904 man
# 863 know
# 779 years
# 719 people
# 692 way
# 690 see
# 682 webs
# 666 said
# 625 many
# 589 htm
# 583 back
# 581 truth
# 539 human
# 508 believers
# age_group 5
# Creating the bag of words...
#
# 549 god
# 471 said
# 424 jan
# 380 man
# 329 life
# 295 time
# 292 know
# 274 people
# 272 jesus
# 271 see
# 264 jo
# 264 sin
# 259 christ
# 247 eternal
# 223 day
# 206 come
# 201 church
# 200 say
# 197 go
# 197 way
#          word  counts  group
# 0        know   12755      0
# 1        love   11759      0
# 2      people   11073      0
# 3        feel   10000      0
# 4        time    9334      0
# 5        life    8137      0
# 6       think    7258      0
# 7       never    7183      0
# 8          go    6836      0
# 9      always    6301      0
# 10    someone    6289      0
# 11        day    5964      0
# 12    friends    5914      0
# 13       back    5804      0
# 14        see    5598      0
# 15      going    5529      0
# 16     things    5395      0
# 17        got    5231      0
# 18      still    5121      0
# 19        way    4993      0
# 0      search   12179      1
# 1        time   11145      1
# 2        site    9468      1
# 3        know    9151      1
# 4      people    9117      1
# 5         web    9006      1
# 6      engine    8037      1
# 7        love    7256      1
# 8        feel    6845      1
# 9        also    6786      1
# ..        ...     ...    ...
# 10        way     692      4
# 11        see     690      4
# 12       webs     682      4
# 13       said     666      4
# 14       many     625      4
# 15        htm     589      4
# 16       back     583      4
# 17      truth     581      4
# 18      human     539      4
# 19  believers     508      4
# 0         god     549      5
# 1        said     471      5
# 2         jan     424      5
# 3         man     380      5
# 4        life     329      5
# 5        time     295      5
# 6        know     292      5
# 7      people     274      5
# 8       jesus     272      5
# 9         see     271      5
# 10         jo     264      5
# 11        sin     264      5
# 12     christ     259      5
# 13    eternal     247      5
# 14        day     223      5
# 15       come     206      5
# 16     church     201      5
# 17        say     200      5
# 18         go     197      5
# 19        way     197      5
#
# [120 rows x 3 columns]

# %%
for group_var in ['age_group','gender']:
    for text_var in ['content','gn']:
        #for noun in [False, True]:
        kbg.keyword_by_group(Data.dropna(),group_var,text_var,nfeature,False,True)
# Out:
# gender U
# Creating the bag of words...
#
# 771 know
# 745 time
# 671 love
# 660 feel
# 595 life
# 593 people
# 459 never
# 458 think
# 414 see
# 404 go
# 373 back
# 351 always
# 349 got
# 345 way
# 343 things
# 331 day
# 326 still
# 311 said
# 304 years
# 283 also
# gender M
# Creating the bag of words...
#
# 13345 time
# 12268 search
# 11517 people
# 10476 know
# 8967 love
# 8843 site
# 8674 web
# 8284 life
# 8110 day
# 8048 engine
# 7703 see
# 7661 also
# 7196 new
# 7185 way
# 7121 may
# 6954 need
# 6605 well
# 6490 go
# 6481 back
# 6187 many
# gender T
# Creating the bag of words...
#
# 407 time
# 352 love
# 349 hosting
# 339 life
# 325 people
# 323 know
# 283 feel
# 279 girl
# 266 web
# 241 go
# 240 think
# 229 never
# 214 way
# 207 see
# 204 always
# 196 going
# 195 got
# 189 day
# 174 first
# 173 also
# gender F
# Creating the bag of words...
#
# 16743 know
# 16633 love
# 13549 feel
# 13367 time
# 12647 people
# 11213 life
# 10179 never
# 9144 go
# 9028 think
# 8393 back
# 8216 always
# 8150 day
# 7459 see
# 7436 things
# 7391 going
# 7279 someone
# 7249 still
# 7095 way
# 7041 got
# 6510 said
# gender U
# Creating the bag of words...
#
# 338 love
# 73 hate
# 52 random
# 51 quote
# 51 thoughts
# 50 people
# 50 write
# 42 know
# 39 music
# 39 need
# 37 think
# 34 believe
# 34 feel
# 33 diary
# 29 someone
# 29 story
# 28 lonelydaisy
# 25 life
# 23 new
# 23 project
# gender M
# Creating the bag of words...
#
# 7391 love
# 1767 music
# 1311 seo
# 1158 know
# 1140 gay
# 917 think
# 904 hate
# 814 new
# 801 people
# 792 need
# 786 someone
# 698 believe
# 680 thoughts
# 663 random
# 608 write
# 574 experience
# 565 writing
# 548 jokes
# 500 limericks
# 496 project
# gender T
# Creating the bag of words...
#
# 184 love
# 74 transgender
# 68 atheist
# 35 people
# 34 know
# 34 wearing
# 32 girl
# 32 person
# 28 write
# 27 crossdresser
# 27 hate
# 26 someone
# 25 think
# 24 hosting
# 24 need
# 21 wear
# 20 email
# 20 panties
# 19 new
# 18 talk
# gender F
# Creating the bag of words...
#
# 8692 love
# 2051 hate
# 1337 people
# 1259 think
# 1254 need
# 1188 know
# 1185 music
# 1182 someone
# 1102 new
# 995 woman
# 903 feel
# 893 write
# 882 thoughts
# 857 believe
# 841 random
# 773 experience
# 711 project
# 706 girlfriend
# 695 person
# 687 member
