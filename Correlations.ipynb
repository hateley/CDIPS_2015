# %%
import csv
import sys
import numpy as np

datafile = 'EP_data.csv'
csv.field_size_limit(sys.maxsize)

def csv_iterator(datafile):
    """Reads 1 row at a time from a csv file, yielding a dict with keys from the header row.
       Adds an 'id' field if there's not one."""
    rownum = 1
    for doc in csv.DictReader(open(datafile, 'rU')):
        id = doc.get('id', str(rownum))
        doc['id'] = id
        rownum += 1
        yield doc


if __name__ == "__main__":
    
    with open("correlations.csv", "w") as out:
        friends = []
        logins = []
        entries = []
        for doc in csv_iterator(datafile):
            friends.append(int(doc['num_friends']))
            logins.append(int(doc['num_logins']))
            entries.append(int(doc['num_entries']))
            if int(doc['id']) % 10000 == 0:
                print (doc['id'])
        friendvlog = np.array([friends,logins])
        friendvent = np.array([friends,entries])
        friendvent = np.array([friends,entries])
        print (np.corrcoef(friendvlog))
        print (np.corrcoef(friendvent))  
        out.write("friends vs. logins: "+str(np.corrcoef(friendvlog))+"\nfriends vs. entries: "+str(np.corrcoef(friendvent)))
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# [[ 1.          0.30896619]
#  [ 0.30896619  1.        ]]
# [[ 1.        -0.0426591]
#  [-0.0426591  1.       ]]
